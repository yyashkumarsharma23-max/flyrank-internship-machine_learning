# %% [markdown]
# <a href="https://colab.research.google.com/github/yyashkumarsharma23-max/flyrank-internship-machine_learning/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yyashkumarsharma23-max/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I have chosen Refresh / Content Opportunity Scoring lane because this lane is closely related to IoT field as there are many testings based on threshold values and logic and the best threshold value makes the model more accurate. I have a keen interest in IoT field as I have make various projects based on that.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Decision:** This work improves the decision of prioritizing which declining web pages need a content refresh first. Instead of guessing, we use data thresholds to find pages that have a genuine drop in traffic but still have high search demand.
# Ex: If we have 1000 pages and we need to choose 10 pages where each page needs less cost and time consumption is also less. The act of choosing pages is based on threshold values and datasets.
#
# **Action:** A human reviewer or the content team acts on this recommendation by inspecting the flagged page and updating, rewriting, or improving its content to regain traffic.
# Ex: Out of choosing 10 pages out of 1000 pages , the pages undergoes certain refinement and data filteration for better accuracy and efficiency.
#
# **Cost of a wrong call:** If the model flags a page incorrectly (a false positive—like a page dropping just because of normal seasonal trends), the content team will waste hours rewriting a page that didn't need fixing. This wastes valuable human effort and money while missing the actual pages that need help.
# Ex: The act of choosing wrong pages requires more cost and more time to execute a particular task.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import pandas as pd

# Loading the starter dataset
df = pd.read_csv('content_refresh_anonymized.csv')

# Calculating the total no. of pages in a dataset
total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])

print(f"Total pages in starter dataset: {total_pages}")
print(f"Pages showing a decline risk: {declining_pages}")
# Out:
# Total pages in starter dataset: 30000
# Pages showing a decline risk: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
#   This is a simple code using only pandas library, first of all the concept that I have explain above about data filteration based on Decision and Action.This code simply first count th total no. of pages in a dataset and those pages which are of no use are filtered and rest pages are undergoes consideration.The total no. of good pages will be Total pages in starter dataset minus Pages showing a decline risk.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
